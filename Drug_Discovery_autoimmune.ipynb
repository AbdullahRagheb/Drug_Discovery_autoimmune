# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdullahRagheb/Drug_Discovery_autoimmune/blob/main/Drug_Discovery_autoimmune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Drug discovery research Final project**
# # supervised By **Dr. Hala Abou Al-Makarm**
#
#
# 1. Amir Mohamed
# 2. Saif Ali
# 3. Ahmed Medhat
# 4. Abdullah Ragheb

# %% [markdown]
# ![DS-logica-diagram-COPY.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Task 0:**
# we need to pick a disease for our research. It’s important to choose a disease with both high unmet medical needs and an opportunity for AI to make an impact.
#
# We might consider:
#
#  1. Cancer
#  2. Alzheimer’s Disease
#  3. Antibiotic Resistance
#  4. Autoimmune Diseases
#  5. Cardiovascular Diseases

# %% [markdown]
# # Choosing **autoimmune diseases** for our research paper on drug discovery with AI is a strategic and meaningful decision for several reasons:
#
#
# #    **Significant Unmet Medical Need:**
#
# 1. Autoimmune diseases affect a large portion of the population worldwide, with conditions like rheumatoid arthritis, lupus **(SLE)**, and multiple sclerosis lacking definitive cures.
#
# 2. Current treatments often only manage symptoms and can have significant side effects, so there's a pressing need for more effective and safer therapies.
#
# #   **Complex Disease Mechanisms Suited for AI:**
#
# 1. Autoimmune diseases involve intricate immune system dysfunctions and complex biological pathways.
#
# 2. AI and machine learning excel at identifying patterns and relationships in complex datasets, making them ideal for unraveling these mechanisms.

# %% [markdown]
# # **1- Installing libraries**

# %%
! pip install chembl_webresource_client

# %% [markdown]
# **Importing libraries**

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # **Search for Target protein**
# # What is IL-23?
#
# This pro-inflammatory protein is the target of potential medications that could help treat autoimmune conditions such as psoriasis, inflammatory bowel disease and rheumatoid arthritis.
#
# The interleukin 23 receptor, or IL-23, has a big job to do. When your body is under attack from threats such as bacteria or fungi, IL-23—a cytokine, or protein, embedded in the body—activates your immune system to protect against illness.
#
# Some people, however, produce too much IL-23. And while that might sound like an even more beneficial response, it’s actually just the opposite. Too much IL-23 increases inflammation and raises the risk for certain autoimmune conditions.

# %% [markdown]
# ![IL12b_Crystal_Structure.rsh.png](data:image/png;base64,...)

# %% [markdown]
# # *References*
#
# *Langrish, C. L., Chen, Y., Blumenschein, W. M., Mattson, J., Basham, B., Sedgwick, J. D., ... & Cua, D. J. (2005). IL-23 drives a pathogenic T cell population that induces autoimmune inflammation. The Journal of Experimental Medicine, 201(2), 233–240. https://doi.org/10.1084/jem.20041257*
#
# *Elhamy, E. M., Abdelrahman, M. Y., Abdelhamed, M. A., & Abdelrahman, H. M. (2020). Advances in understanding the immunopathogenesis of systemic lupus erythematosus. The Journal of Clinical Medicine, 12(17), 5699. https://doi.org/10.3390/jcm12175699*
#
# *Papadakis, K. A., & Targan, S. R. (2006). Role of cytokines in the pathogenesis of inflammatory bowel disease. Gastroenterology, 130(5), 1580–1596. https://doi.org/10.1053/j.gastro.2006.01.067*
#
# *Nishimura, K., Takagi, Y., & Wada, Y. (2020). IL-23-related immune axis in autoimmune diseases and cancer. Frontiers in Immunology, 11, 156. https://doi.org/10.3389/fimmu.2020.00156*

# %% [markdown]
# ### **Target** **IL_23**

# %%
target_IL_23 = new_client.target
target_IL_23_query = target_IL_23.search('IL-23')
targets_IL_23 = pd.DataFrame.from_dict(target_IL_23_query)
targets_IL_23
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'xref_id': 'P24470', 'xref_name': None, 'xre...
# ..                                                 ...
# 150                                                 []
# 151                                                 []
# 152                                                 []
# 153                                                 []
# 154                                                 []
#
#                        organism                    pref_name  score  \
# 0                  Homo sapiens      Interleukin-23 receptor   29.0
# 1                  Mus musculus      Interleukin-23 receptor   29.0
# 2                  Homo sapiens               Interleukin-23   27.0
# ...

# %% [markdown]
# **Select and retrieve bioactivity data for IL-23**

# %%
selected_target_IL_23 = targets_IL_23.target_chembl_id[0]
selected_target_IL_23
# Out:
# 'CHEMBL4296013'

# %%
activity_IL_23 = new_client.activity
res_IL_23 = activity_IL_23.filter(target_chembl_id=selected_target_IL_23).filter(standard_type="IC50")

# %%
df_IL_23 = pd.DataFrame.from_dict(res_IL_23)

# %%
df_IL_23
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None     18564265                  []
# 1           None             None     18564266                  []
# 2           None             None     19320881                  []
# 3           None             None     19320882                  []
# 4           None             None     19320883                  []
# ...          ...              ...          ...                 ...
# 1102        None             None     19322450                  []
# 1103        None             None     19322451                  []
# 1104        None             None     19322452                  []
# 1105        None             None     19322453                  []
# 1106        None             None     19322454                  []
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL4202303  Binding affinity to recombinant human flag/His...
# ...

# %% [markdown]
# # **Handling missing data**

# %% [markdown]
# **Handling missing data for IL-23**

# %%
df_IL_23_c = df_IL_23[df_IL_23.standard_value.notna()]
df_IL_23_c = df_IL_23_c[df_IL_23.canonical_smiles.notna()]
df_IL_23_c
# Out:
# <ipython-input-60-4c067688c5fb>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_IL_23_c = df_IL_23_c[df_IL_23.canonical_smiles.notna()]
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None     18564265                  []
# 1           None             None     18564266                  []
# 2           None             None     19320881                  []
# 3           None             None     19320882                  []
# 4           None             None     19320883                  []
# ...          ...              ...          ...                 ...
# 1102        None             None     19322450                  []
# 1103        None             None     19322451                  []
# 1104        None             None     19322452                  []
# 1105        None             None     19322453                  []
# ...

# %%
len(df_IL_23_c.canonical_smiles.unique())
# Out:
# 846

# %%
df_IL_23_c_dr = df_IL_23_c.drop_duplicates(['canonical_smiles'])
df_IL_23_c_dr
# Out:
#      action_type activity_comment  activity_id activity_properties  \
# 0           None             None     18564265                  []
# 2           None             None     19320881                  []
# 3           None             None     19320882                  []
# 4           None             None     19320883                  []
# 5           None             None     19320884                  []
# ...          ...              ...          ...                 ...
# 1096        None             None     19322444                  []
# 1097        None             None     19322445                  []
# 1102        None             None     19322450                  []
# 1103        None             None     19322451                  []
# 1104        None             None     19322452                  []
#
#      assay_chembl_id                                  assay_description  \
# 0      CHEMBL4202303  Binding affinity to recombinant human flag/His...
# ...

# %%
df_IL_23_c_dr.to_csv('autoimmune_Task_0_data.csv', index=False)

# %% [markdown]
# # **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df_IL_23_c_dr_1 = df_IL_23_c_dr[selection]
df_IL_23_c_dr_1
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 2         CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3         CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4         CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 5         CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ...                 ...                                                ...
# 1096      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 1097      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 1102      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 1103      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 1104      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#      standard_value
# 0               2.7
# 2             113.0
# ...

# %%
df_IL_23_c_dr_1.to_csv('autoimmune_bioactivity_data.csv', index=False)

# %% [markdown]
# # **Labeling compounds as either being active, inactive or intermediate**
#
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df_IL_23_c_dr_2 = pd.read_csv('autoimmune_bioactivity_data.csv')

# %%
bioactivity_threshold = []
for i in df_IL_23_c_dr_2.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df_IL_23_c_dr_3 = pd.concat([df_IL_23_c_dr_2, bioactivity_class], axis=1)
df_IL_23_c_dr_3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#      standard_value   class
# 0               2.7  active
# ...

# %%
df_IL_23_c_dr_3.to_csv('autoimmune_bioactivity_data_labeled.csv', index=False)

# %% [markdown]
# # **Task 1: Descriptor Calculation and Exploratory Data**

# %%
df = pd.read_csv('autoimmune_bioactivity_data_labeled.csv')
df
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#      standard_value   class
# 0               2.7  active
# ...

# %%
df_no_smiles = df.drop(columns='canonical_smiles')

# %%
smiles = []

for i in df.canonical_smiles.tolist():
  cpd = str(i).split('.')
  cpd_longest = max(cpd, key = len)
  smiles.append(cpd_longest)

smiles = pd.Series(smiles, name = 'canonical_smiles')

# %%
df_clean_smiles = pd.concat([df_no_smiles,smiles], axis=1)
df_clean_smiles
# Out:
#     molecule_chembl_id  standard_value   class  \
# 0        CHEMBL4206167             2.7  active
# 1        CHEMBL4567228           113.0  active
# 2        CHEMBL4555885            32.0  active
# 3        CHEMBL4529484            25.0  active
# 4        CHEMBL4577218            39.0  active
# ..                 ...             ...     ...
# 841      CHEMBL4466684            25.0  active
# 842      CHEMBL4550541            25.0  active
# 843      CHEMBL4543067            10.0  active
# 844      CHEMBL4476734            10.0  active
# 845      CHEMBL4436303            10.0  active
#
#                                       canonical_smiles
# 0    CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1    CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2    CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3    CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4    CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                                                 ...
# ...

# %% [markdown]
# # **Calculate Lipinski descriptors**
#
# Christopher Lipinski, a scientist at Pfizer, developed a set of guidelines, commonly known as the **Rule of Five** or **Lipinski's Rule**, to assess the druglikeness of chemical compounds. These guidelines are based on the pharmacokinetic profile of a compound, which encompasses Absorption, Distribution, Metabolism, and Excretion (**ADME**). By analyzing all orally active drugs approved by the FDA, Lipinski formulated this rule to predict the likelihood of a compound being an effective oral drug.
#
# **Lipinski's Rule of Five includes the following criteria:**
#
# 1. Molecular weight less than 500 Daltons
# 2. Octanol-water partition coefficient (LogP) less than 5
# 3. No more than 5 hydrogen bond donors
# 4. No more than 10 hydrogen bond acceptors

# %% [markdown]
# # **Import rdkit**

# %%
# !pip install rdkit
# Out:
# ...
#      |████████████████████████████████| 29.5 MB 67.6 MB/s
# ...

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# # **Calculate descriptors**

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem)
        moldata.append(mol)

    baseData= np.arange(1,1)
    i=0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1

    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)

    return descriptors

# %%
df_lipinski = lipinski(df_clean_smiles.canonical_smiles)
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0    1623.817 -5.72320        22.0           22.0
# 1    1915.237 -3.57483        27.0           24.0
# 2    1806.109 -5.81470        26.0           25.0
# 3    1835.107 -6.49520        27.0           25.0
# 4    1847.162 -4.98313        27.0           24.0
# ..        ...      ...         ...            ...
# 841  1824.010 -5.41830        22.0           24.0
# 842  1833.022 -7.39773        25.0           25.0
# 843  1721.987 -4.82360        23.0           22.0
# 844  1885.163 -4.27370        24.0           24.0
# 845  1883.191 -3.12000        24.0           23.0
#
# [846 rows x 4 columns]

# %%
df_combined = pd.concat([df,df_lipinski], axis=1)

# %%
df_combined
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#      standard_value   class        MW     LogP  NumHDonors  NumHAcceptors
# ...

# %% [markdown]
# # **Convert IC50 to pIC50**
# To allow IC50 data to be more uniformly distributed, we will convert IC50 to the negative logarithmic scale which is essentially -log10(IC50).
#
# **note**: Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', axis=1)

    return x

# %%
df_combined.standard_value.describe()
# Out:
# count       846.000000
# mean       3238.684043
# std        8835.852059
# min           2.700000
# 25%          25.000000
# 50%         222.500000
# 75%        1000.000000
# max      100000.000000
# Name: standard_value, dtype: float64

# %%
-np.log10( (10**-9)* 100000000 )
# Out:
# 1.0

# %%
-np.log10( (10**-9)* 10000000000 )
# Out:
# -1.0

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', axis=1)

    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#       class        MW     LogP  NumHDonors  NumHAcceptors  standard_value_norm
# ...

# %%
df_norm.standard_value_norm.describe()
# Out:
# count       846.000000
# mean       3238.684043
# std        8835.852059
# min           2.700000
# 25%          25.000000
# 50%         222.500000
# 75%        1000.000000
# max      100000.000000
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#       class        MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %% [markdown]
# # **Removing the 'intermediate' bioactivity class**

# %%
df_2class = df_final[df_final['class'] != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL4206167  CC(=O)N[C@H]1CCSC[C@@H](C(=O)N[C@@H](Cc2ccc(OC...
# 1        CHEMBL4567228  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 2        CHEMBL4555885  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 3        CHEMBL4529484  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# 4        CHEMBL4577218  CC(=O)N[C@@H](CS)C(=O)N[C@@H](CCC(N)=O)C(=O)N[...
# ..                 ...                                                ...
# 841      CHEMBL4466684  CC(=O)N[C@H](Cc1ccccc1)C(=O)N[C@H]1CCSC[C@@H](...
# 842      CHEMBL4550541  CC(=O)N[C@H](CCCNC(=N)N)C(=O)N[C@H]1CCSC[C@@H]...
# 843      CHEMBL4543067  CC(=O)NCCCC[C@H](NC(=O)C(C)(C)NC(=O)[C@H](Cc1c...
# 844      CHEMBL4476734  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
# 845      CHEMBL4436303  COc1ccc(C[C@H](NC(=O)[C@@H](NC(=O)[C@H](CCC(N)...
#
#       class        MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %%
df_2class.to_csv('autoimmune_bioactivity_data_pIC50.csv')
